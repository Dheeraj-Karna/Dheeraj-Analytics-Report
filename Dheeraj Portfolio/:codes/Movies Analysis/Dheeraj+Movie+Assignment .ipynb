# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv('Movie+Assignment+Data.csv')# Write your code for importing the csv file here

movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 5038                      2.0                   318.0     Daphne Zuniga
# 5039                      NaN                   319.0     Valorie Curry
# 5040                      0.0                     0.0     Maxwell Moody
# 5041                      0.0                   489.0     Daniel Henney
# 5042                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 5038                   637.0          NaN                     Comedy|Drama
# 5039                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 5040                     0.0          NaN            Drama|Horror|Thriller
# 5041                   946.0      10443.0             Comedy|Drama|Romance
# 5042                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 5038  ...                  6.0  English   Canada             NaN          NaN
# 5039  ...                359.0  English      USA           TV-14          NaN
# 5040  ...                  3.0  English      USA             NaN       1400.0
# 5041  ...                  9.0  English      USA           PG-13          NaN
# 5042  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 5038      2013.0                  470.0        7.7           NaN
# 5039         NaN                  593.0        7.5         16.00
# 5040      2013.0                    0.0        6.3           NaN
# 5041      2012.0                  719.0        6.3          2.35
# 5042      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 5038                   84
# 5039                32000
# 5040                   16
# 5041                  660
# 5042                  456
#
# [5043 rows x 28 columns]

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here

movies.shape[0] 
#inspecting the DataFrame shape

#movies.columns
#inspecting the Dataframe columns

movies.dtypes 
#inspecting the variable type of the column name
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here
movies.isnull().sum() 
# column wise null count
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here

movies.isnull().sum(axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       14
#         ..
# 5038     4
# 5039     5
# 5040     4
# 5041     2
# 5042     0
# Length: 5043, dtype: int64

# %%
# Write your code for column-wise null percentages here

movies.isnull().mean() * 100
# Out:
# color                         0.376760
# director_name                 2.062265
# num_critic_for_reviews        0.991473
# duration                      0.297442
# director_facebook_likes       2.062265
# actor_3_facebook_likes        0.456078
# actor_2_name                  0.257783
# actor_1_facebook_likes        0.138806
# gross                        17.529248
# genres                        0.000000
# actor_1_name                  0.138806
# movie_title                   0.000000
# num_voted_users               0.000000
# cast_total_facebook_likes     0.000000
# actor_3_name                  0.456078
# facenumber_in_poster          0.257783
# plot_keywords                 3.033908
# movie_imdb_link               0.000000
# num_user_for_reviews          0.416419
# language                      0.277613
# country                       0.099147
# content_rating                6.008328
# budget                        9.756098
# title_year                    2.141582
# actor_2_facebook_likes        0.257783
# imdb_score                    0.000000
# aspect_ratio                  6.523895
# movie_facebook_likes          0.000000
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

mov_temp=movies.drop(columns=['color','director_facebook_likes','actor_1_facebook_likes','actor_2_facebook_likes','actor_3_facebook_likes',
                     'actor_2_name','cast_total_facebook_likes','actor_3_name','duration','facenumber_in_poster','content_rating','country',
                     'movie_imdb_link','aspect_ratio','plot_keywords'])

mov_temp.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here

mov_temp.isnull().mean()*100
# Out:
# director_name              2.062265
# num_critic_for_reviews     0.991473
# gross                     17.529248
# genres                     0.000000
# actor_1_name               0.138806
# movie_title                0.000000
# num_voted_users            0.000000
# num_user_for_reviews       0.416419
# language                   0.277613
# budget                     9.756098
# title_year                 2.141582
# imdb_score                 0.000000
# movie_facebook_likes       0.000000
# dtype: float64

# %%
mov_temp.dropna(subset=['gross','budget'],inplace=True)

mov_temp[['gross','budget']].isnull().sum()
# Out:
# gross     0
# budget    0
# dtype: int64

# %% [markdown]
# -  ### Subtask 2.4: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here

mov_temp['language'].isnull().sum()
# Out:
# 4

# %%
mov_temp[['language','movie_title']]
# Out:
#      language                                movie_title
# 0     English                                    Avatar
# 1     English  Pirates of the Caribbean: At World's End
# 2     English                                   Spectre
# 3     English                     The Dark Knight Rises
# 5     English                               John Carter
# ...       ...                                        ...
# 5033  English                                    Primer
# 5034  English                                    Cavite
# 5035  Spanish                               El Mariachi
# 5037  English                                 Newlyweds
# 5042  English                         My Date with Drew
#
# [3891 rows x 2 columns]

# %%
mov_temp['language'].fillna('English',inplace=True)

mov_temp['language']
# Out:
# 0       English
# 1       English
# 2       English
# 3       English
# 5       English
#          ...
# 5033    English
# 5034    English
# 5035    Spanish
# 5037    English
# 5042    English
# Name: language, Length: 3891, dtype: object

# %%
mov_temp['language'].isnull().sum()
# Out:
# 0

# %%
mov_temp.shape
# Out:
# (3891, 13)

# %% [markdown]
# -  ### Subtask 2.5: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
mov_temp.shape[0]/movies.shape[0]*100
# Out:
# 77.15645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
mov_temp['budget'] = (mov_temp['budget'] / 1000000).round (2)

mov_temp['gross'] = (mov_temp['gross'] / 1000000).round (2)

mov_temp[['budget','gross']]
# Out:
#       budget   gross
# 0     237.00  760.51
# 1     300.00  309.40
# 2     245.00  200.07
# 3     250.00  448.13
# 5     263.70   73.06
# ...      ...     ...
# 5033    0.01    0.42
# 5034    0.01    0.07
# 5035    0.01    2.04
# 5037    0.01    0.00
# 5042    0.00    0.09
#
# [3891 rows x 2 columns]

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Plot `profit` (y-axis) vs `budget` (x- axis) and observe the outliers using the appropriate chart type.
#     4. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
mov_temp['profit']= mov_temp['gross'] - mov_temp['budget']
mov_temp[['gross','budget','movie_title']]
# Out:
#             gross       budget  \
# 0     760505847.0  237000000.0
# 1     309404152.0  300000000.0
# 2     200074175.0  245000000.0
# 3     448130642.0  250000000.0
# 4             NaN          NaN
# ...           ...          ...
# 5038          NaN          NaN
# 5039          NaN          NaN
# 5040          NaN       1400.0
# 5041      10443.0          NaN
# 5042      85222.0       1100.0
#
#                                             movie_title
# 0                                               Avatar
# 1             Pirates of the Caribbean: At World's End
# 2                                              Spectre
# 3                                The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens    ...
# ...                                                 ...
# 5038                           Signed Sealed Delivered
# 5039                         The Following
# 5040                              A Plague So Pleasant
# 5041                                  Shanghai Calling
# 5042                                 My Date with Drew
#
# [5043 rows x 3 columns]

# %%
# Write your code for sorting the dataframe here
mov_temp.sort_values(by='profit', ascending = False)
mov_temp[['gross','budget','profit','movie_title']].head (10)
# Out:
#          gross       budget       profit  \
# 0  760505847.0  237000000.0  523505847.0
# 1  309404152.0  300000000.0    9404152.0
# 2  200074175.0  245000000.0  -44925825.0
# 3  448130642.0  250000000.0  198130642.0
# 4          NaN          NaN          NaN
# 5   73058679.0  263700000.0 -190641321.0
# 6  336530303.0  258000000.0   78530303.0
# 7  200807262.0  260000000.0  -59192738.0
# 8  458991599.0  250000000.0  208991599.0
# 9  301956980.0  250000000.0   51956980.0
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# 4  Star Wars: Episode VII - The Force Awakens    ...
# 5                                       John Carter
# 6                                      Spider-Man 3
# 7                                           Tangled
# 8                           Avengers: Age of Ultron
# 9            Harry Potter and the Half-Blood Prince

# %%
# Write code for profit vs budget plot here
import seaborn as sns

sns.regplot(data=mov_temp, x='budget',y='profit')
# Out:
# <Axes: xlabel='budget', ylabel='profit'>

# %%
# Write your code to get the top 10 profiting movies here

mov_top_10=mov_temp.sort_values(by='profit', ascending= False).head(10)
mov_top_10[['movie_title','profit','language']]

type(mov_top_10)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have noticed a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`. Note that the same `movie_title` can be there in different languages.

# %%
# Write your code for dropping duplicate values here
mov_top_10.drop_duplicates(inplace=True)
mov_top_10[['movie_title','profit','language','director_name']]
# Out:
#                                      movie_title  profit language  \
# 0                                        Avatar   523.51  English
# 29                               Jurassic World   502.18  English
# 26                                      Titanic   458.67  English
# 3024         Star Wars: Episode IV - A New Hope   449.94  English
# 3080                 E.T. the Extra-Terrestrial   424.45  English
# 17                                 The Avengers   403.28  English
# 509                               The Lion King   377.78  English
# 240   Star Wars: Episode I - The Phantom Menace   359.54  English
# 66                              The Dark Knight   348.32  English
#
#           director_name
# 0         James Cameron
# 29      Colin Trevorrow
# 26        James Cameron
# 3024       George Lucas
# 3080   Steven Spielberg
# 17          Joss Whedon
# 509        Roger Allers
# 240        George Lucas
# 66    Christopher Nolan

# %%
# Write code for repeating subtask 2 here

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

IMDb_Top_250 = (
    mov_temp[mov_temp['num_voted_users'] > 25000]
    .sort_values(by='imdb_score', ascending=False)
    .head(250)
)

IMDb_Top_250['Rank'] = range(1, 251)

IMDb_Top_250[['movie_title','language','director_name','num_voted_users','imdb_score','Rank']].tail(10)
# Out:
#                       movie_title  language     director_name  \
# 3595                The Wrestler    English  Darren Aronofsky
# 3510                  Veer-Zaara      Hindi       Yash Chopra
# 3452                       Crash    English       Paul Haggis
# 353                  Toy Story 2    English     John Lasseter
# 1713                       Glory    English      Edward Zwick
# 788                Almost Famous    English     Cameron Crowe
# 2863       Letters from Iwo Jima   Japanese    Clint Eastwood
# 1735               Walk the Line    English     James Mangold
# 1993  The World's Fastest Indian    English   Roger Donaldson
# 1606                The Notebook    English   Nick Cassavetes
#
#       num_voted_users  imdb_score  Rank
# 3595           251349         7.9   241
# 3510            34449         7.9   242
# 3452           361169         7.9   243
# 353            385871         7.9   244
# 1713           101888         7.9   245
# 788            207287         7.9   246
# 2863           132149         7.9   247
# 1735           188637         7.9   248
# 1993            44198         7.9   249
# 1606           396396         7.9   250

# %%
 # Write your code to extract top foreign language films from 'IMDb_Top_250' here

Top_Foreign_Lang_Films = IMDb_Top_250[IMDb_Top_250['language'] != 'English']

#Top_Foreign_Lang_Film[Top_Foreign_Lang_Film['movie_title'].str.contains("Veer-Zaara", case=False, na=False)]

Top_Foreign_Lang_Films[['movie_title','language','director_name','num_voted_users','Rank']]
# Out:
#                               movie_title    language  \
# 4498      The Good, the Bad and the Ugly      Italian
# 4029                         City of God   Portuguese
# 4747                       Seven Samurai     Japanese
# 2373                       Spirited Away     Japanese
# 4259                 The Lives of Others       German
# 4921                  Children of Heaven      Persian
# 4659                        A Separation      Persian
# 1298                              Amélie       French
# 4105                              Oldboy       Korean
# 2323                   Princess Mononoke     Japanese
# 1329            Baahubali: The Beginning       Telugu
# 2970                            Das Boot       German
# 2734                          Metropolis       German
# 2829                            Downfall       German
# 4033                            The Hunt       Danish
# 3550                           Incendies       French
# 2551                     Pan's Labyrinth      Spanish
# 4000            The Secret in Their Eyes      Spanish
# 2047                Howl's Moving Castle     Japanese
# 2830                      The Sea Inside      Spanish
# 4461                     The Celebration       Danish
# 4267                       Amores Perros      Spanish
# 2914  Tae Guk Gi: The Brotherhood of War       Korean
# 3423                               Akira     Japanese
# 3553                         Elite Squad   Portuguese
# 3344                     My Name Is Khan        Hindi
# 4284                   Waltz with Bashir       Hebrew
# 3456                          Persepolis       French
# 4897                A Fistful of Dollars      Italian
# 4144                     Central Station   Portuguese
# 3677                          The Chorus       French
# 2493                                Hero     Mandarin
# 4415                         Nine Queens      Spanish
# 2605      Crouching Tiger, Hidden Dragon     Mandarin
# 1171                                Hero     Mandarin
# 3264                               Amour       French
# 3510                          Veer-Zaara        Hindi
# 2863               Letters from Iwo Jima     Japanese
#
#                          director_name  num_voted_users  Rank
# 4498                      Sergio Leone           503509     8
# 4029                Fernando Meirelles           533200    15
# 4747                    Akira Kurosawa           229012    18
# 2373                    Hayao Miyazaki           417971    21
# 4259  Florian Henckel von Donnersmarck           259379    41
# 4921                      Majid Majidi            27882    45
# 4659                    Asghar Farhadi           151812    47
# 1298                Jean-Pierre Jeunet           534262    49
# 4105                    Chan-wook Park           356181    50
# 2323                    Hayao Miyazaki           221552    52
# 1329                    S.S. Rajamouli            62756    57
# 2970                 Wolfgang Petersen           168203    59
# 2734                        Fritz Lang           111841    62
# 2829               Oliver Hirschbiegel           248354    69
# 4033                 Thomas Vinterberg           170155    81
# 3550                  Denis Villeneuve            80429    86
# 2551                Guillermo del Toro           467234    94
# 4000              Juan José Campanella           131831    98
# 2047                    Hayao Miyazaki           214091   101
# 2830                Alejandro Amenábar            64556   129
# 4461                 Thomas Vinterberg            65951   133
# 4267             Alejandro G. Iñárritu           173551   138
# 2914                       Je-kyu Kang            31943   143
# 3423                   Katsuhiro Ôtomo           106160   152
# 3553                      José Padilha            81644   153
# 3344                       Karan Johar            69759   160
# 4284                        Ari Folman            46107   161
# 3456                 Vincent Paronnaud            70194   172
# 4897                      Sergio Leone           147566   182
# 4144                     Walter Salles            28951   193
# 3677              Christophe Barratier            44151   209
# 2493                       Yimou Zhang           149414   211
# 4415                  Fabián Bielinsky            38215   212
# 2605                           Ang Lee           217740   213
# 1171                       Yimou Zhang           149414   222
# 3264                    Michael Haneke            70382   236
# 3510                       Yash Chopra            34449   242
# 2863                    Clint Eastwood           132149   247

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.  Incase of a tie in IMDb score between two directors, sort them alphabetically.

# %%
# Write your code for extracting the top 10 directors here

# Group by director_name and calculate mean IMDb score

director_avg = mov_temp.groupby('director_name')['imdb_score'].mean()

director_avg_df = director_avg.reset_index()

top10director= director_avg_df.sort_values(by='imdb_score', ascending=False)

top10director.head(10)

top10director
# Out:
#            director_name  imdb_score
# 1675           Tony Kaye         8.6
# 216      Charles Chaplin         8.6
# 45      Alfred Hitchcock         8.5
# 1017        Majid Majidi         8.5
# 302      Damien Chazelle         8.5
# ...                  ...         ...
# 1          Aaron Seltzer         2.7
# 688      Jason Friedberg         2.6
# 1429     Roger Christian         2.4
# 40             Alex Zamm         2.3
# 1705  Vondie Curtis-Hall         2.1
#
# [1753 rows x 2 columns]

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here

genres_split= mov_temp['genres'].str.split('|')

mov_temp['genres_1']= genres_split.apply(lambda x: x[0] if len(x)>0 else [])

mov_temp['genres_2']= genres_split.apply(lambda x: x[1] if len(x)>1 else x[0])

mov_temp[['genres_1','genres_2']]

mov_temp.dtypes
# Out:
# director_name              object
# num_critic_for_reviews    float64
# gross                     float64
# genres                     object
# actor_1_name               object
# movie_title                object
# num_voted_users             int64
# num_user_for_reviews      float64
# language                   object
# budget                    float64
# title_year                float64
# imdb_score                float64
# movie_facebook_likes        int64
# profit                    float64
# genres_1                   object
# genres_2                   object
# dtype: object

# %%
# Write your code for grouping the dataframe here

mov_temp['genre_combo'] = mov_temp['genres_1'].astype(str) + '+' + mov_temp['genres_2'].astype(str)
mov_temp[['genre_combo','movie_title','gross']]
# Out:
#                   genre_combo                                movie_title  \
# 0            Action+Adventure                                    Avatar
# 1            Action+Adventure  Pirates of the Caribbean: At World's End
# 2            Action+Adventure                                   Spectre
# 3             Action+Thriller                     The Dark Knight Rises
# 5            Action+Adventure                               John Carter
# ...                       ...                                        ...
# 5033             Drama+Sci-Fi                                    Primer
# 5034        Thriller+Thriller                                    Cavite
# 5035             Action+Crime                               El Mariachi
# 5037             Comedy+Drama                                 Newlyweds
# 5042  Documentary+Documentary                         My Date with Drew
#
#        gross
# 0     760.51
# 1     309.40
# 2     200.07
# 3     448.13
# 5      73.06
# ...      ...
# 5033    0.42
# 5034    0.07
# 5035    2.04
# 5037    0.00
# 5042    0.09
#
# [3891 rows x 3 columns]

# %%
# Write your code for getting the 5 most popular combo of genres here

PopGenre = (
    mov_temp.groupby('genre_combo')['gross']
    .mean()
    .reset_index(name='mean_gross')
    .sort_values(by='mean_gross', ascending=False)
    .head(5)
)
PopGenre
# Out:
#             genre_combo  mean_gross
# 83        Family+Sci-Fi  434.950000
# 28     Adventure+Sci-Fi  228.628750
# 18  Adventure+Animation  116.998462
# 24     Adventure+Family  116.520000
# 1      Action+Adventure  110.382566

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_users_for_review` and identify the actors which have the highest mean.
#     5. Observe the change in number of voted users over decades using a bar chart. Create a column called `decade` which represents the decade to which every movie belongs to. For example, the  `title_year`  year 1923, 1925 should be stored as 1920s. Sort the dataframe based on the column `decade`, group it by `decade` and find the sum of users voted in each decade. Store this in a new data frame called `df_by_decade`.

# %%
# Write your code for creating three new dataframes here
 
# Include all movies in which Meryl_Streep is the lead

Meryl_Streep = mov_temp[mov_temp['actor_1_name']== 'Meryl Streep']

Meryl_Streep[['actor_1_name','movie_title']]
# Out:
#       actor_1_name                movie_title
# 410   Meryl Streep          It's Complicated
# 1106  Meryl Streep            The River Wild
# 1204  Meryl Streep             Julie & Julia
# 1408  Meryl Streep     The Devil Wears Prada
# 1483  Meryl Streep           Lions for Lambs
# 1575  Meryl Streep             Out of Africa
# 1618  Meryl Streep              Hope Springs
# 1674  Meryl Streep            One True Thing
# 1925  Meryl Streep                 The Hours
# 2781  Meryl Streep             The Iron Lady
# 3135  Meryl Streep  A Prairie Home Companion

# %%
# Include all movies in which Leo_Caprio is the lead

Leo_Caprio = mov_temp[mov_temp['actor_1_name']== 'Leonardo DiCaprio']

Leo_Caprio[['actor_1_name','movie_title']]
# Out:
#            actor_1_name                movie_title
# 26    Leonardo DiCaprio                   Titanic
# 50    Leonardo DiCaprio          The Great Gatsby
# 97    Leonardo DiCaprio                 Inception
# 179   Leonardo DiCaprio              The Revenant
# 257   Leonardo DiCaprio               The Aviator
# 296   Leonardo DiCaprio          Django Unchained
# 307   Leonardo DiCaprio             Blood Diamond
# 308   Leonardo DiCaprio   The Wolf of Wall Street
# 326   Leonardo DiCaprio         Gangs of New York
# 361   Leonardo DiCaprio              The Departed
# 452   Leonardo DiCaprio            Shutter Island
# 641   Leonardo DiCaprio              Body of Lies
# 911   Leonardo DiCaprio       Catch Me If You Can
# 990   Leonardo DiCaprio                 The Beach
# 1114  Leonardo DiCaprio        Revolutionary Road
# 1422  Leonardo DiCaprio  The Man in the Iron Mask
# 1453  Leonardo DiCaprio                  J. Edgar
# 1560  Leonardo DiCaprio    The Quick and the Dead
# 2067  Leonardo DiCaprio             Marvin's Room
# 2757  Leonardo DiCaprio            Romeo + Juliet
# 3476  Leonardo DiCaprio          The Great Gatsby

# %%
# Include all movies in which Brad_Pitt is the lead

Brad_Pitt = mov_temp[mov_temp['actor_1_name']== 'Brad Pitt']
Brad_Pitt[['actor_1_name','movie_title']]
# Out:
#      actor_1_name                                        movie_title
# 101     Brad Pitt               The Curious Case of Benjamin Button
# 147     Brad Pitt                                              Troy
# 254     Brad Pitt                                    Ocean's Twelve
# 255     Brad Pitt                                  Mr. & Mrs. Smith
# 382     Brad Pitt                                          Spy Game
# 400     Brad Pitt                                    Ocean's Eleven
# 470     Brad Pitt                                              Fury
# 611     Brad Pitt                              Seven Years in Tibet
# 683     Brad Pitt                                        Fight Club
# 792     Brad Pitt                  Sinbad: Legend of the Seven Seas
# 940     Brad Pitt  Interview with the Vampire: The Vampire Chroni...
# 1490    Brad Pitt                                  The Tree of Life
# 1722    Brad Pitt  The Assassination of Jesse James by the Coward...
# 2204    Brad Pitt                                             Babel
# 2333    Brad Pitt                                        By the Sea
# 2682    Brad Pitt                               Killing Them Softly
# 2898    Brad Pitt                                      True Romance

# %%
# Write your code for combining the three dataframes here

Combined = pd.concat([Meryl_Streep,Brad_Pitt,Leo_Caprio])

Combined.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes', 'profit', 'genres_1', 'genres_2',
#        'genre_combo'],
#       dtype='object')

# %%
# Write your code for grouping the combined dataframe here

Combined.groupby('actor_1_name')[['num_critic_for_reviews','num_user_for_reviews']].mean().reset_index()
# Out:
#         actor_1_name  num_critic_for_reviews  num_user_for_reviews
# 0          Brad Pitt              245.000000            742.352941
# 1  Leonardo DiCaprio              330.190476            914.476190
# 2       Meryl Streep              181.454545            297.181818

# %%
# Write the code for finding the mean of critic reviews and audience reviews here
Combined[['num_critic_for_reviews','num_user_for_reviews']].mean()
# Out:
# num_critic_for_reviews    267.244898
# num_user_for_reviews      716.183673
# dtype: float64

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!

# %%
# Write the code for calculating decade here
mov_temp['decade']= (mov_temp['title_year']//10*10).astype(int).astype(str)+'s'

mov_temp[['movie_title','decade','num_user_for_reviews']]
# Out:
#                                     movie_title decade  num_user_for_reviews
# 0                                       Avatar   2000s                3054.0
# 1     Pirates of the Caribbean: At World's End   2000s                1238.0
# 2                                      Spectre   2010s                 994.0
# 3                        The Dark Knight Rises   2010s                2701.0
# 5                                  John Carter   2010s                 738.0
# ...                                         ...    ...                   ...
# 5033                                    Primer   2000s                 371.0
# 5034                                    Cavite   2000s                  35.0
# 5035                               El Mariachi   1990s                 130.0
# 5037                                 Newlyweds   2010s                  14.0
# 5042                         My Date with Drew   2000s                  84.0
#
# [3891 rows x 3 columns]

# %%
# Write your code for creating the data frame df_by_decade here 

df_by_decade=(
    mov_temp.groupby('decade')['num_user_for_reviews'].sum()
    .reset_index(name='users_voted_in_each_decade')
    .sort_values(by='decade',ascending = False)
)   

df_by_decade
# Out:
#   decade  users_voted_in_each_decade
# 9  2010s                    309081.0
# 8  2000s                    667040.0
# 7  1990s                    207595.0
# 6  1980s                     52542.0
# 5  1970s                     22765.0
# 4  1960s                      9424.0
# 3  1950s                      1854.0
# 2  1940s                       928.0
# 1  1930s                      1849.0
# 0  1920s                       485.0

# %%
# Write your code for plotting number of voted users vs decade

#mov_temp[['num_voted_users','decade']]

sns.scatterplot(data=mov_temp, x='decade',y='num_voted_users')
# Out:
# <Axes: xlabel='decade', ylabel='num_voted_users'>

# %%
mov_temp.to_csv('mov_temp_data.csv', index=False)

# %%
mov_temp.columns
# Out:
# Index(['director_name', 'num_critic_for_reviews', 'gross', 'genres',
#        'actor_1_name', 'movie_title', 'num_voted_users',
#        'num_user_for_reviews', 'language', 'budget', 'title_year',
#        'imdb_score', 'movie_facebook_likes', 'profit'],
#       dtype='object')

# %%
mov_temp.dtypes
# Out:
# director_name              object
# num_critic_for_reviews    float64
# gross                     float64
# genres                     object
# actor_1_name               object
# movie_title                object
# num_voted_users             int64
# num_user_for_reviews      float64
# language                   object
# budget                    float64
# title_year                float64
# imdb_score                float64
# movie_facebook_likes        int64
# profit                    float64
# dtype: object
